# %%
import numpy as np
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# loading the dataframe
df_main = pd.read_csv('sample30.csv')

# %%
df_reco = df_main[['name','reviews_username','reviews_rating']]

# %%
# check for null values

df_reco.isnull().sum()
# Out:
# name                 0
# reviews_username    63
# reviews_rating       0
# dtype: int64

# %%
# dropping rows with NaN values

df_reco.dropna(axis=0, inplace=True)

# %%
# check for duplicates

df_reco.duplicated().sum()
# Out:
# 2198

# %%
# dropping the duplicates

df_reco.drop_duplicates(inplace=True)

# %%
# check for duplicates based on subset of 'name' and 'reviews_username'

df_reco.duplicated(subset=['name','reviews_username']).sum()
# Out:
# 151

# %% [markdown]
# From above we note that we have certain users who have given two or more different ratings to the same products. Let us impute those ratings the average ratings.

# %%
# get the average ratings for duplicated rows

df_mean = df_reco[df_reco.duplicated(subset=['name','reviews_username'], keep=False)].groupby(
    by=['name', 'reviews_username']).mean()

df_mean
# Out:
#                                                                       reviews_rating
# name                                               reviews_username
# 100:Complete First Season (blu-Ray)                dontdodat                3.500000
# Alex Cross (dvdvideo)                              mookie                   4.500000
# Aveeno Baby Continuous Protection Lotion Sunscr... byamazon customer        2.666667
# Avery174 Ready Index Contemporary Table Of Cont... gellis                   4.500000
#                                                    the office guro          3.500000
# ...                                                                              ...
# Tostitos Bite Size Tortilla Chips                  debb                     4.000000
#                                                    rick                     4.500000
#                                                    sandy                    3.000000
# Windex Original Glass Cleaner Refill 67.6oz (2 ... laura                    1.500000
#                                                    suri                     3.500000
#
# [135 rows x 1 columns]

# %%
# left merge the df_reco and df_mean dataframes over 'name' and 'reviews_username'

df_merged = df_reco.merge(df_mean, how='left' , on=['name', 'reviews_username']).sort_values(
    by=['name', 'reviews_username'])

df_merged.head()
# Out:
#                                                     name reviews_username  \
# 19543  0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. ...           brewno
# 19545  0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. ...            embum
# 19547  0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. ...           granny
# 19542  0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. ...      smokey bear
# 19546  0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. ...         spicesea
#
#        reviews_rating_x  reviews_rating_y
# 19543                 3               NaN
# 19545                 5               NaN
# 19547                 5               NaN
# 19542                 3               NaN
# 19546                 5               NaN

# %%
df_merged.isnull().sum()
# Out:
# name                    0
# reviews_username        0
# reviews_rating_x        0
# reviews_rating_y    27453
# dtype: int64

# %% [markdown]
# Since we have very few such rows, we would have many NaN values in reviews_rating_y column. Let us concatenate the dataframe such that we get average values from reviews_rating_y column and normal ratings from reviews_rating_x column

# %%
A = df_merged[df_merged['reviews_rating_y'].isnull()][['name','reviews_username','reviews_rating_x']]
A.rename(columns={'reviews_rating_x':'reviews_rating_final'}, inplace=True)

B = df_merged[df_merged['reviews_rating_y'].isnull()==False][['name','reviews_username','reviews_rating_y']]
B.rename(columns={'reviews_rating_y':'reviews_rating_final'}, inplace=True)

df_final= pd.concat([A, B])
df_final.sort_values(by=['name', 'reviews_username'])
# Out:
#                                                     name reviews_username  \
# 19543  0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. ...           brewno
# 19545  0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. ...            embum
# 19547  0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. ...           granny
# 19542  0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. ...      smokey bear
# 19546  0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. ...         spicesea
# ...                                                  ...              ...
# 20525           Yes To Grapefruit Rejuvenating Body Wash           sheila
# 20534           Yes To Grapefruit Rejuvenating Body Wash            skeel
# 20531           Yes To Grapefruit Rejuvenating Body Wash             td33
# 20553           Yes To Grapefruit Rejuvenating Body Wash       trishaxo2u
# 20544           Yes To Grapefruit Rejuvenating Body Wash         yogagirl
#
#        reviews_rating_final
# 19543                   3.0
# 19545                   5.0
# 19547                   5.0
# 19542                   3.0
# 19546                   5.0
# ...                     ...
# 20525                   1.0
# 20534                   4.0
# 20531                   3.0
# 20553                   5.0
# 20544                   5.0
#
# [27739 rows x 3 columns]

# %%
# check for duplicates from `df_final` df
df_final.duplicated().sum()
# Out:
# 151

# %%
# drop duplicates from 'df_final' df

df_final.drop_duplicates(inplace=True)

# %%
df_final.head()
# Out:
#                                                     name reviews_username  \
# 19543  0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. ...           brewno
# 19545  0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. ...            embum
# 19547  0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. ...           granny
# 19542  0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. ...      smokey bear
# 19546  0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. ...         spicesea
#
#        reviews_rating_final
# 19543                   3.0
# 19545                   5.0
# 19547                   5.0
# 19542                   3.0
# 19546                   5.0

# %%
df_final['reviews_rating_final'].value_counts()
# Out:
# 5.000000    19456
# 4.000000     5434
# 3.000000     1183
# 1.000000     1048
# 2.000000      369
# 4.500000       75
# 3.500000       15
# 2.500000        2
# 1.500000        2
# 3.333333        2
# 2.666667        1
# 3.666667        1
# Name: reviews_rating_final, dtype: int64

# %% [markdown]
#     R: rating matrix (user X item)
#     P: User features matrix (user X latent feature)
#     Q: Item features matrix (item X laten feature)
#     K: latent features
#     steps: iterations
#     alpha: learning rate
#     beta: regularization parameter

# %%
# Create a user-product matrix.
df_pivot = df_final.pivot(
    index='reviews_username',
    columns='name',
    values='reviews_rating_final'
).fillna(0)


R = np.array(df_pivot)
# N: num of User
N = R.shape[0]
# M: num of Movie
M = R.shape[1]
# K: latent features
K = 50

P = np.random.rand(N,K)
Q = np.random.rand(M,K)

# %%
def matrix_factorization(R, P, Q, K, steps=50, alpha=0.0002, beta=0.02):
    '''
    R: rating matrix
    P: |U| * K (User features matrix)
    Q: |D| * K (Item features matrix)
    K: latent features
    steps: iterations
    alpha: learning rate
    beta: regularization parameter'''
    
    Q = Q.T

    for step in range(steps):
        for i in range(len(R)):
            for j in range(len(R[i])):
                if R[i][j] > 0:
                    # calculate error
                    eij = R[i][j] - np.dot(P[i,:],Q[:,j])

                    for k in range(K):
                        # calculate gradient with a and beta parameter
                        P[i][k] = P[i][k] + alpha * (2 * eij * Q[k][j] - beta * P[i][k])
                        Q[k][j] = Q[k][j] + alpha * (2 * eij * P[i][k] - beta * Q[k][j])

#         eR = np.dot(P,Q)

        # checking the error
        e = 0
        for i in range(len(R)):

            for j in range(len(R[i])):
                if R[i][j] > 0:
                    e = e + pow(R[i][j] - np.dot(P[i,:],Q[:,j]), 2)
                    for k in range(K):
                        e = e + (beta/2) * (pow(P[i][k],2) + pow(Q[k][j],2))   # applying L2 regularisation
        # 0.001: local minimum
        if e < 0.001:

            break

    return P, Q.T

# %%
def matrix_factorization_optimised(R, P, Q, K, steps=50, alpha=0.0002, beta=0.02):
    '''
    R: rating matrix
    P: |U| * K (User features matrix)
    Q: |D| * K (Item features matrix)
    K: latent features
    steps: iterations
    alpha: learning rate
    beta: regularization parameter'''
    
    Q = Q.T

    for step in range(steps):
        for i in range(len(R)):
            for j in range(len(R[i])):
                if R[i][j] > 0:
                    # calculate error
                    eij = R[i][j] - np.dot(P[i,:],Q[:,j])

#                     for k in range(K):
                        # calculate gradient with a and beta parameter
                    P[i,:] = P[i,:] + alpha * (2 * eij * Q[:,j].T - beta * P[i,:])
                    Q[:,j] = Q[:,j] + alpha * (2 * eij * P[i,:].T - beta * Q[:,j])

#         eR = np.dot(P,Q)

        # checking the error
        e = 0
        for i in range(len(R)):
            for j in range(len(R[i])):
                if R[i][j] > 0:
                    e = e + pow(R[i][j] - np.dot(P[i,:],Q[:,j]), 2)
                    for k in range(K):
                        e = e + (beta/2) * (pow(P[i][k],2) + pow(Q[k][j],2))   # applying L2 regularisation
        # 0.001: local minimum
        if e < 0.001:

            break

    return P, Q.T

# %%
nP, nQ = matrix_factorization_optimised(R, P, Q, K)

nR = np.dot(nP, nQ.T)

# %%
pred_R = pd.DataFrame(nR, columns = df_pivot.columns, index = df_pivot.index)

# %%
# checking predicted ratings with MF method
pred_R
# Out:
# name              0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. Fire File Chest  \
# reviews_username
# 00dog3                                                     7.150294
# 00sab00                                                    7.736406
# 01impala                                                   7.714596
# 02dakota                                                   7.170768
# 02deuce                                                    6.521045
# ...                                                             ...
# zxcsdfd                                                    6.265867
# zxjki                                                      6.634312
# zyiah4                                                     6.555006
# zzdiane                                                    8.951885
# zzz1127                                                    6.582740
#
# name              100:Complete First Season (blu-Ray)  \
# reviews_username
# 00dog3                                       5.519434
# 00sab00                                      4.235384
# 01impala                                     5.731142
# 02dakota                                     4.799320
# 02deuce                                      5.252639
# ...                                               ...
# zxcsdfd                                      3.967552
# zxjki                                        4.864927
# zyiah4                                       4.968052
# zzdiane                                      6.058828
# zzz1127                                      4.841382
#
# name              2017-2018 Brownline174 Duraflex 14-Month Planner 8 1/2 X 11 Black  \
# reviews_username
# 00dog3                                                     7.079770
# 00sab00                                                    7.079238
# 01impala                                                   8.123919
# 02dakota                                                   6.277110
# 02deuce                                                    8.482999
# ...                                                             ...
# zxcsdfd                                                    7.519615
# zxjki                                                      6.071578
# zyiah4                                                     8.646245
# zzdiane                                                    7.525995
# zzz1127                                                    7.894176
#
# name              2x Ultra Era with Oxi Booster, 50fl oz  \
# reviews_username
# 00dog3                                          9.749926
# 00sab00                                         6.956261
# 01impala                                       10.334370
# 02dakota                                        8.213799
# 02deuce                                         7.656528
# ...                                                  ...
# zxcsdfd                                         7.167004
# zxjki                                           7.330549
# zyiah4                                         10.219678
# zzdiane                                         9.501307
# zzz1127                                         9.665559
#
# name              42 Dual Drop Leaf Table with 2 Madrid Chairs"  \
# reviews_username
# 00dog3                                                11.042287
# 00sab00                                               10.028495
# 01impala                                              12.067533
# 02dakota                                              10.881713
# 02deuce                                               10.756380
# ...                                                         ...
# zxcsdfd                                                9.070708
# zxjki                                                 11.008057
# zyiah4                                                10.565182
# zzdiane                                               11.536640
# zzz1127                                               11.876745
#
# name              4C Grated Parmesan Cheese 100% Natural 8oz Shaker  \
# reviews_username
# 00dog3                                                     6.678009
# 00sab00                                                    8.307530
# 01impala                                                   9.118010
# 02dakota                                                   6.630253
# 02deuce                                                    8.799478
# ...                                                             ...
# zxcsdfd                                                    7.465212
# zxjki                                                      8.159163
# zyiah4                                                     7.750344
# zzdiane                                                    7.774639
# zzz1127                                                    9.290876
#
# name              5302050 15/16 FCT/HOSE ADAPTOR  \
# reviews_username
# 00dog3                                 11.696839
# 00sab00                                12.107881
# 01impala                               12.230252
# 02dakota                               10.900526
# 02deuce                                12.031361
# ...                                          ...
# zxcsdfd                                10.640175
# zxjki                                  10.895540
# zyiah4                                 10.674643
# zzdiane                                12.474834
# zzz1127                                11.762438
#
# name              Africa's Best No-Lye Dual Conditioning Relaxer System Super  \
# reviews_username
# 00dog3                                                     6.439968
# 00sab00                                                    6.982579
# 01impala                                                   7.192361
# 02dakota                                                   5.464641
# 02deuce                                                    6.465298
# ...                                                             ...
# zxcsdfd                                                    6.129092
# zxjki                                                      6.541809
# zyiah4                                                     6.541763
# zzdiane                                                    7.433385
# zzz1127                                                    6.110810
#
# name              Alberto VO5 Salon Series Smooth Plus Sleek Shampoo  \
# reviews_username
# 00dog3                                                     8.258086
# 00sab00                                                    8.128253
# 01impala                                                   9.986191
# 02dakota                                                   6.930283
# 02deuce                                                    8.037675
# ...                                                             ...
# zxcsdfd                                                    7.892971
# zxjki                                                      7.496563
# zyiah4                                                     9.108351
# zzdiane                                                    8.157762
# zzz1127                                                    8.417829
#
# name              Alex Cross (dvdvideo)  ...  Walkers Stem Ginger Shortbread  \
# reviews_username                         ...
# 00dog3                         4.714687  ...                       11.236139
# 00sab00                        4.123104  ...                        9.702003
# 01impala                       4.464586  ...                       13.305093
# 02dakota                       3.780186  ...                       11.340491
# 02deuce                        3.563356  ...                       10.602341
# ...                                 ...  ...                             ...
# zxcsdfd                        3.989972  ...                       10.080374
# zxjki                          3.776395  ...                        9.858839
# zyiah4                         4.367355  ...                       11.990090
# zzdiane                        4.425532  ...                       12.853627
# zzz1127                        4.079660  ...                       10.534748
#
# name              Wallmount Server Cabinet (450mm, 9 RU)  \
# reviews_username
# 00dog3                                         11.390738
# 00sab00                                         9.321165
# 01impala                                       12.578117
# 02dakota                                       11.634236
# 02deuce                                        11.411359
# ...                                                  ...
# zxcsdfd                                         9.886476
# zxjki                                          10.505681
# zyiah4                                         11.184025
# zzdiane                                        11.372923
# zzz1127                                        11.933355
#
# name              Way Basics 3-Shelf Eco Narrow Bookcase Storage Shelf, Espresso - Formaldehyde Free - Lifetime Guarantee  \
# reviews_username
# 00dog3                                                     5.844891
# 00sab00                                                    6.075149
# 01impala                                                   6.664514
# 02dakota                                                   5.040549
# 02deuce                                                    6.313700
# ...                                                             ...
# zxcsdfd                                                    5.673058
# zxjki                                                      5.246307
# zyiah4                                                     5.544045
# zzdiane                                                    6.252841
# zzz1127                                                    7.256135
#
# name              WeatherTech 40647 14-15 Outlander Cargo Liners Behind 2nd Row, Black  \
# reviews_username
# 00dog3                                                     6.788433
# 00sab00                                                    5.803756
# 01impala                                                   7.542204
# 02dakota                                                   4.539202
# 02deuce                                                    6.236421
# ...                                                             ...
# zxcsdfd                                                    5.848622
# zxjki                                                      5.494603
# zyiah4                                                     6.354455
# zzdiane                                                    6.007771
# zzz1127                                                    7.033317
#
# name              Wedding Wishes Wedding Guest Book  Weleda Everon Lip Balm  \
# reviews_username
# 00dog3                                    12.100599                8.007179
# 00sab00                                   11.010840                8.036310
# 01impala                                  13.035477                8.374233
# 02dakota                                  11.109477                6.516942
# 02deuce                                   12.299358                6.831235
# ...                                             ...                     ...
# zxcsdfd                                   10.555968                6.446202
# zxjki                                     11.187844                8.273601
# zyiah4                                    11.792505                8.586349
# zzdiane                                   12.149711                8.913349
# zzz1127                                   12.703684                6.853363
#
# name              Wilton Black Dots Standard Baking Cups  \
# reviews_username
# 00dog3                                         10.206940
# 00sab00                                        10.514212
# 01impala                                       12.280614
# 02dakota                                        9.162541
# 02deuce                                         9.991723
# ...                                                  ...
# zxcsdfd                                         8.808352
# zxjki                                          10.324178
# zyiah4                                         10.373727
# zzdiane                                        11.383230
# zzz1127                                        10.959034
#
# name              Windex Original Glass Cleaner Refill 67.6oz (2 Liter)  \
# reviews_username
# 00dog3                                                     4.257564
# 00sab00                                                    3.807626
# 01impala                                                   5.368482
# 02dakota                                                   3.854837
# 02deuce                                                    4.088185
# ...                                                             ...
# zxcsdfd                                                    3.713176
# zxjki                                                      4.054322
# zyiah4                                                     4.153259
# zzdiane                                                    5.062307
# zzz1127                                                    4.918597
#
# name              Yes To Carrots Nourishing Body Wash  \
# reviews_username
# 00dog3                                       5.207056
# 00sab00                                      4.811508
# 01impala                                     5.982731
# 02dakota                                     4.453180
# 02deuce                                      5.267679
# ...                                               ...
# zxcsdfd                                      4.529923
# zxjki                                        4.921018
# zyiah4                                       4.960819
# zzdiane                                      5.453087
# zzz1127                                      4.953276
#
# name              Yes To Grapefruit Rejuvenating Body Wash
# reviews_username
# 00dog3                                            3.077792
# 00sab00                                           4.655842
# 01impala                                          4.356612
# 02dakota                                          4.278425
# 02deuce                                           4.011708
# ...                                                    ...
# zxcsdfd                                           3.718866
# zxjki                                             3.406819
# zyiah4                                            5.527479
# zzdiane                                           4.960017
# zzz1127                                           4.006844
#
# [24914 rows x 271 columns]

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------
